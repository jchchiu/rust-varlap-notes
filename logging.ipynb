# %% [markdown]
# # LOGGING

# %% [markdown]
# https://www.carolinemorton.co.uk/blog/rust-tracing-logging-fundamentals/
# - At first we were experimenting with simple logging using the 'log' crate
# - However if we want to implement multithreading, we need to be able to deal with asynchronous logging, and the logging crate needs to be able to structure logging in an understandle format as compared to if it was just logging whenever (i.e. logs from different threads would overlap and thus be confusing)

# %% [markdown]
# https://www.carolinemorton.co.uk/blog/rust-tracing-structured-fields-and-spans/
